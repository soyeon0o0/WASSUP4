# %%
from IPython.display import Image

# 이미지 경로를 절대 경로로 지정
image_path = 'C:\workspace\WASSUP4\image\포포퐆.jpg'  # 이미지 경로를 확인 후 수정
display(Image(filename=image_path))
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\User\AppData\Local\Temp\ipykernel_36872\2144369847.py:4: SyntaxWarning: invalid escape sequence '\w'
#   image_path = 'C:\workspace\WASSUP4\image\포포퐆.jpg'  # 이미지 경로를 확인 후 수정
